# %%
import pandas as pd
import matplotlib.pyplot as plt
dfX1 = pd.read_csv('X1.csv', index_col = 0)
dfX2 = pd.read_csv('X2.csv', index_col = 0)
dfX2 #.columns
# Out:
#              MET1        TYR3       LEU5        LEU7       LEU12      PHE30  \
# 0     -170.944721 -113.344419  57.010241  120.108393  175.434114 -37.097834
# 1      159.266980  -95.510689  68.459815 -170.911168  173.668153 -16.036094
# 2      175.488427 -107.819181  66.209213  171.650487 -177.912459 -38.838652
# 3     -169.850033  -87.873733  62.118063  102.145301 -177.811459 -29.299222
# 4     -174.944673 -104.654300  72.315860   68.632876  166.194462 -44.815321
# ...           ...         ...        ...         ...         ...        ...
# 15996 -176.969680  -74.740766  69.262623   93.754237 -169.696924 -42.040036
# 15997 -166.517922 -101.414821  65.837445  152.706857  157.963095 -33.139135
# 15998 -147.134073  -98.356227  67.898876 -171.353570 -178.854831 -31.231702
# 15999  168.369920  -96.220380  57.366935 -177.567615   72.920084 -47.600483
# 16000 -170.210201  -98.221619  79.339889  101.229696   67.547008 -46.552173
#
#             TYR33       TRP43      TYR45       PHE52
# 0       90.340782   67.194784  66.562543   86.499929
# 1      101.509192   70.654214  72.956643   74.453345
# 2       77.848356   63.593501  59.350844   96.121375
# 3       85.459885   80.547845  80.185507   90.631261
# 4       79.359474   81.655402  67.863342   68.365266
# ...           ...         ...        ...         ...
# 15996  -90.590212 -102.155939  46.959689  104.914842
# 15997 -109.110991  -82.502623  84.212693   75.522880
# 15998  -81.454399  -86.468803  58.188320   92.731320
# 15999  -83.690794  -79.632383  70.182558   85.437747
# 16000  -86.140556  -71.995109  66.466489   70.662330
#
# [16001 rows x 10 columns]

# %%
def chi_plot(df, chi_name):
    cols = df.columns #['ILE182','MET170','PHE144','PHE105']
    N = len(cols)
    fig, axes = plt.subplots(nrows=N, ncols=1)
    for i, col in enumerate(cols):
        dfX2[str(col)].plot(ax=axes[i], figsize=(20,50), fontsize=20)
        axes[i].set_ylim(-200,200)
        axes[i].set_title(label=f'{col}-{chi_name}', fontsize=20)
    plt.tight_layout()

# %%
#cols = ['PHE12', 'PHE105', 'PHE123', 'TRP143','PHE144','PHE146','TYR173']
#N = len(cols)
#chi_plot(dfX1, 'X1')
chi_plot(dfX2, 'X2')

# %%
dfX2.plot.kde(figsize=(20,10), linewidth=5)
plt.legend(loc=2, prop={'size': 30})
plt.xlim(-180,180)
# Out:
# (-180.0, 180.0)
